# %%
# Import needed modules
import numpy as np
from matplotlib import pyplot as plt
from yroots.subdivision import solve

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Summary
#
# For our tests, we tried to replicate the tests used in the Chebfun Test Suite. We have a test comparing the norms of the found roots versus the "actual" roots, which may either be the actual roots or the roots found using Marching Squares. The default tolerance is chebeps $*$ 1000, which is approximately 2.2204e-13. The norms calculated for the roots are printed below where it indicates whether it passed or failed.
#
# We also have a test that compares the residuals to a given tolerance. Again, the default tolerance is chebeps $*$ 1000.
#
# In most instances, YRoots does not pass the norm test nor the residuals test with these tolerances. However, there are some instances where YRoots is close, and these are summarized below in the Close Failures list. A notable example is [Test 6.2](#test6.2), where YRoots identifies the correct number of roots (6) where Chebfun and Marching Squares found 5. YRoots also has smaller residuals on this test.
#
# YRoots is consistently finding residuals within the range of 1e-11 or 1e-12, if not smaller.
#
# To run the tests, first run the import cell and the [necessary test functions cell](#neededfuncs) located at the end of the notebook.
#
# ## Summary of tests that pass:
#
# abs_approx_tol = 1.e-12
# rel_approx_tol = 1.e-8
#
# ### Residual test: $\frac{12}{27}$
# * 1.1
# * 1.3
# * 1.4
# * 1.5
# * 2.5
# * 4.1
# * 6.1
# * 6.2
# * 6.3
# * 7.2 - One better than Chebfun's, one worse
# * 7.3 - Both worse than Chebfun's
# * 9.2 - Both worse than Chebfun's
#
# ### Chebfun norm test: $\frac{15}{27}$
# * 1.1
# * 1.3
# * 2.1
# * 2.3
# * 2.4
# * 2.5
# * 4.1
# * 5.1
# * 6.1** - YRoots finds a spurious root
# * 6.2** - YRoots identifies a correct extra root.
# * 7.1
# * 7.3
# * 9.1
# * 9.2
# * 10.1
#
# ### MS norm test: $\frac{12}{27}$
# * 1.1
# * 1.3
# * 1.4
# * 1.5
# * 2.3
# * 2.4
# * 2.5
# * 4.1
# * 7.1
# * 9.1
# * 9.2
# * 10.1
#
# ## Honorable mentions
#
# ### Residual test
# * 1.2 (off by 9.e-15), both better than Chebfun's
# * 2.1 (off by 2.3e-13), both worse than Chebfun's
# * 2.2 (off by 2e-14), one worse than Chebfun's, one match
# * 2.3 (off by 3e-14, 4.1e-13), both worse than Chebfun's
# * 2.4 (off by 1.1e-13, 2.6e-13), one better than Chebfun's, one worse.
# * 3.1 (off by ~3.8e-13), both worse than Chebfun's
# * 3.2 (off by ~4.3e-13, 2.3e-13), one better than Chebfun's, one worse.
# * 5.1 (off by ~2.7e-13), both worse than Chebfun's.
# * 7.1 (off by ~6.4e-13), both worse than Chebfun's.
# * 8.2 (off by ~5.1e-13, ~5.7e-13), both worse than Chebfun's
# * 9.1 (off by ~2e-14), both worse than Chebfun's
#
# ### Chebfun norm test
# * 7.4 (off by ~4e-13, ~3.6e-13)
# * 8.1 (off by ~1.3e-13)
# * 8.2 (off by ~1.1e-13)
#
# ### MS norm test
# * 8.1 (off by ~1.3e-13)
# * 8.1 (off by ~1.1e-13)

# %%
# Test 1.1
f = lambda x,y: 144*(x**4+y**4)-225*(x**2+y**2) + 350*x**2*y**2+81
g = lambda x,y: y-x**6
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest1_1ms.csv', delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest1_1.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 1.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 568
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.5282 98.0634  1.4085  0.      0.    ]
# =========================================================
# Test 1.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 3.7395568157567285e-14
# The norm of the difference in y values: 5.690835935677602e-14
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 3.7395568157567285e-14
# The norm of the difference in y values: 5.851673850589455e-14
# YRoots max residuals:
# 	f0: 3.851141627819743e-12
# 	f1: 3.4139358007223564e-14
# Chebfun max residuals:
# 	f0: 4.263256414560601e-14
# 	f1: 7.771561172376096e-16
# MS/Actual max residuals:
# 	f0: 2.842170943040401e-14
# 	f1: 3.3306690738754696e-16
# Number of YRoots residual values <= MS/Actual residual values are: 0
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %% [markdown]
# # We beat Chebfun in Residuals

# %%
# Test 1.2
f = lambda x,y: (y**2-x**3)*((y-0.7)**2-(x-0.3)**3)*((y+0.2)**2-(x+0.8)**3)*((y+0.2)**2-(x-0.8)**3)
g = lambda x,y: ((y+.4)**3-(x-.4)**2)*((y+.3)**3-(x-.3)**2)*((y-.5)**3-(x+.6)**2)*((y+0.3)**3-(2*x-0.8)**3)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest1_2.csv',delimiter=',')


verbose_pass_or_fail([f,g], yroots, cheb_roots=chebfun_roots, test_num=1.2, MSroots=None)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1924
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.6757 97.5572  1.7672  0.      0.    ]
# =========================================================
# Test 1.2
# 	 Residual test: fail
# 	 Chebfun fails residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 1.0097302001659913e-06
# The norm of the difference in y values: 9.780204254377581e-07
# YRoots max residuals:
# 	f0: 3.4405681481941067e-12
# 	f1: 1.8164161358930856e-12
# Chebfun max residuals:
# 	f0: 1.9875428628747228e-12
# 	f1: 3.5848829919831295e-13
# Number of YRoots residual values <= to Chebfun residual values are: 6
# =========================================================

# %%
# Test 1.3
f = lambda x,y: y**2-x**3
g = lambda x,y: (y+.1)**3-(x-.1)**2 
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest1_3.csv', delimiter=',')
MSroots = np.loadtxt('tests/chebfun_test_output/cftest1_3ms.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots, test_num=1.3, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0.   0. 100.   0.]
# =========================================================
# Test 1.3
# 	 Residual test: pass
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 1.0647364715731862e-12
# The norm of the difference in y values: 1.3633980217881965e-12
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 1.065087714325515e-12
# The norm of the difference in y values: 1.361948336435235e-12
# YRoots max residuals:
# 	f0: 4.867354891531506e-14
# 	f1: 2.795029832580731e-14
# Chebfun max residuals:
# 	f0: 1.717376241217039e-16
# 	f1: 1.761286429202702e-16
# MS/Actual max residuals:
# 	f0: 6.591949208711867e-17
# 	f1: 8.109832250191573e-17
# Number of YRoots residual values <= MS/Actual residual values are: 1
# Number of YRoots residual values <= to Chebfun residual values are: 2
# =========================================================

# %%
# Test 1.4
f = lambda x,y: x - y + .5
g = lambda x,y: x + y
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
# Single root has to be in matrix form because yroots
# returns the roots in matrix form.
a_roots = np.array([[-.25, .25]])

verbose_pass_or_fail([f,g], yroots, a_roots, test_num=1.4)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0. 100.   0.   0.]
# =========================================================
# Test 1.4
# 	 Residual test: pass
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 5.551115123125783e-17
# The norm of the difference in y values: 2.7755575615628914e-17
# YRoots max residuals:
# 	f0: 0.0
# 	f1: 8.326672684688674e-17
# MS/Actual max residuals:
# 	f0: 0.0
# 	f1: 0.0
# Number of YRoots residual values <= MS/Actual residual values are: 1
# Number of YRoots residual values <= to Chebfun residual values are: 1
# =========================================================

# %%
# Test 1.5
f = lambda x,y: y + x/2 + 1/10
g = lambda x,y: y - 2.1*x + 2
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
# Single root has to be in matrix form because yroots
# returns the roots in matrix form.
a_roots = np.array([[0.730769230769231, -0.465384615384615]])

verbose_pass_or_fail([f,g], yroots, a_roots, 1.5)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0. 100.   0.   0.]
# =========================================================
# Test 1.5
# 	 Residual test: pass
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 2.220446049250313e-16
# The norm of the difference in y values: 4.996003610813204e-16
# YRoots max residuals:
# 	f0: 1.3877787807814457e-16
# 	f1: 0.0
# MS/Actual max residuals:
# 	f0: 4.718447854656915e-16
# 	f1: 0.0
# Number of YRoots residual values <= MS/Actual residual values are: 2
# Number of YRoots residual values <= to Chebfun residual values are: 2
# =========================================================

# %%
# Test 2.1
f = lambda x,y: np.cos(10*x*y)
g = lambda x,y: x + y**2
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest2_1ms.csv', delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest2_1.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 2.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 673
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 6.3893 91.8276  1.7831  0.      0.    ]
# =========================================================
# Test 2.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 5.607355016962163e-13
# The norm of the difference in y values: 6.265558861125687e-13
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 5.607355016962163e-13
# The norm of the difference in y values: 6.265558861125687e-13
# YRoots max residuals:
# 	f0: 3.696315305847039e-12
# 	f1: 4.999889391399392e-13
# Chebfun max residuals:
# 	f0: 7.044813998280222e-16
# 	f1: 7.771561172376096e-16
# MS/Actual max residuals:
# 	f0: 7.044813998280222e-16
# 	f1: 7.771561172376096e-16
# Number of YRoots residual values <= MS/Actual residual values are: 0
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %%
# Test 2.2
f = lambda x,y: x
g = lambda x,y: (x-.9999)**2 + y**2-1
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest2_2ms.csv', delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest2_2.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 2.2, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 4066
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.     95.7206  4.2794  0.      0.    ]
# =========================================================
# Test 2.2
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 2.117582368135751e-22
# The norm of the difference in y values: 5.582049654288823e-11
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 2.117582368135751e-22
# The norm of the difference in y values: 5.579720053558622e-11
# YRoots max residuals:
# 	f0: 2.117582368135751e-22
# 	f1: 1.4908074774666602e-12
# Chebfun max residuals:
# 	f0: 0.0
# 	f1: 3.3306690738754696e-16
# MS/Actual max residuals:
# 	f0: 0.0
# 	f1: 2.220446049250313e-16
# Number of YRoots residual values <= MS/Actual residual values are: 1
# Number of YRoots residual values <= to Chebfun residual values are: 2
# =========================================================

# %%
# Test 2.3
f = lambda x,y: np.sin(4*(x + y/10 + np.pi/10))
g = lambda x,y: np.cos(2*(x-2*y+ np.pi/7))
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest2_3ms.csv', delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest2_3.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 2.3, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 274
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 2.5547 94.5255  2.9197  0.      0.    ]
# =========================================================
# Test 2.3
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 6.327531231259025e-12
# The norm of the difference in y values: 5.910692938045909e-12
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 6.327756906454612e-12
# The norm of the difference in y values: 5.910707022046094e-12
# YRoots max residuals:
# 	f0: 2.5473179121604517e-11
# 	f1: 1.9623031147984674e-11
# Chebfun max residuals:
# 	f0: 1.6538921594855151e-15
# 	f1: 2.603302919143008e-15
# MS/Actual max residuals:
# 	f0: 2.3429107291650482e-15
# 	f1: 2.603302919143008e-15
# Number of YRoots residual values <= MS/Actual residual values are: 0
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %%
import time
# Test 2.4
f = lambda x,y: np.exp(x-2*x**2-y**2)*np.sin(10*(x+y+x*y**2))
g = lambda x,y: np.exp(-x+2*y**2+x*y**2)*np.sin(10*(x-y-2*x*y**2))
print("Because this was listed as \"slow\", we timed it. On the same machine, there was little difference.")
start = time.time()
solve([f,g],[-1,-1],[1,1])
end = time.time()
print("Time:", end - start,"s")
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest2_4ms.csv', delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest2_4.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 2.4, cheb_roots=chebfun_roots)
# Out:
# Because this was listed as "slow", we timed it. On the same machine, there was little difference.
# Percent Finished: 100%
# Total intervals checked was 12364
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 1.8845 96.328   1.7874  0.      0.    ]
# Time: 8.527059316635132 s
# Percent Finished: 100%
# Total intervals checked was 12364
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 1.8845 96.328   1.7874  0.      0.    ]
# =========================================================
# Test 2.4
# 	 Residual test: fail
# 	 Chebfun fails residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 1.090063395972512e-12
# The norm of the difference in y values: 1.1850441945663432e-12
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 1.092666289159594e-12
# The norm of the difference in y values: 1.1860222767512526e-12
# YRoots max residuals:
# 	f0: 3.5727271837592537e-12
# 	f1: 6.283562477728069e-12
# Chebfun max residuals:
# 	f0: 9.045784489794772e-15
# 	f1: 1.7212075398037472e-12
# MS/Actual max residuals:
# 	f0: 1.1910268923530595e-14
# 	f1: 1.7212075398037472e-12
# Number of YRoots residual values <= MS/Actual residual values are: 5
# Number of YRoots residual values <= to Chebfun residual values are: 10
# =========================================================

# %%
# Test 2.5
f = lambda x,y: 2*y*np.cos(y**2)*np.cos(2*x)-np.cos(y)
g = lambda x,y: 2*np.sin(y**2)*np.sin(2*x)-np.sin(x)
print("Because this was listed as \"slow\", we timed it. On the same machine, there was little difference.")
start = time.time()
solve([f,g],[-4,-4],[4,4])
end = time.time()
print("Time:", end - start, "s")

yroots = solve([f,g],[-4,-4],[4,4], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest2_5ms.csv', delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest2_5.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 2.5, tol=2.220446049250313e-12, cheb_roots=chebfun_roots)
# Out:
# Because this was listed as "slow", we timed it. On the same machine, there was little difference.
# Percent Finished: 100%
# Total intervals checked was 8230
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 3.0377 95.4678  1.4945  0.      0.    ]
# Time: 5.4488420486450195 s
# Percent Finished: 100%
# Total intervals checked was 8230
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 3.0377 95.4678  1.4945  0.      0.    ]
# =========================================================
# Test 2.5
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 6.75152436741029e-12
# The norm of the difference in y values: 2.017144218145623e-12
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 6.761046337002546e-12
# The norm of the difference in y values: 2.018544708116516e-12
# YRoots max residuals:
# 	f0: 7.1522787692401835e-12
# 	f1: 5.852204375437516e-12
# Chebfun max residuals:
# 	f0: 2.291500322826323e-13
# 	f1: 1.0558220964185239e-13
# MS/Actual max residuals:
# 	f0: 2.381428387820961e-13
# 	f1: 4.8183679268731794e-14
# Number of YRoots residual values <= MS/Actual residual values are: 4
# Number of YRoots residual values <= to Chebfun residual values are: 7
# =========================================================

# %%
# Test 3.1
# No MS roots to compare to, so we compare to Chebfun's roots.
f = lambda x,y: ((x-.3)**2+2*(y+0.3)**2-1)
g = lambda x,y: ((x-.49)**2+(y+.5)**2-1)*((x+0.5)**2+(y+0.5)**2-1)*((x-1)**2+(y-0.5)**2-1)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest3_1.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots=None, test_num=3.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 682
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.     98.0938  1.9062  0.      0.    ]
# =========================================================
# Test 3.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 3.368487801687418e-10
# The norm of the difference in y values: 7.256287335310777e-11
# YRoots max residuals:
# 	f0: 6.5580874064608e-13
# 	f1: 3.170473118725694e-14
# Chebfun max residuals:
# 	f0: 8.881784197001252e-16
# 	f1: 5.712564177884184e-16
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %%
# Test 3.2
# No MS roots to compare to, so we compare to Chebfun's roots.
f = lambda x,y: ((x-0.1)**2+2*(y-0.1)**2-1)*((x+0.3)**2+2*(y-0.2)**2-1)*((x-0.3)**2+2*(y+0.15)**2-1)*((x-0.13)**2+2*(y+0.15)**2-1)
g = lambda x,y: (2*(x+0.1)**2+(y+0.1)**2-1)*(2*(x+0.1)**2+(y-0.1)**2-1)*(2*(x-0.3)**2+(y-0.15)**2-1)*((x-0.21)**2+2*(y-0.15)**2-1)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest3_2.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots=None, cheb_roots=chebfun_roots, test_num=3.2)
# Out:
# Percent Finished: 100%
# Total intervals checked was 10267
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.6331 97.4774  1.8895  0.      0.    ]
# =========================================================
# Test 3.2
# 	 Residual test: fail
# 	 Chebfun fails residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 2.5267499958543215e-09
# The norm of the difference in y values: 4.154389107135336e-09
# YRoots max residuals:
# 	f0: 7.037141033673397e-13
# 	f1: 4.928866189105958e-13
# Chebfun max residuals:
# 	f0: 2.1791205326277763e-14
# 	f1: 8.34699616627686e-13
# Number of YRoots residual values <= to Chebfun residual values are: 4
# =========================================================

# %%
# Test 4.1
# This system hs 4 true roots, but ms fails (finds 5).
f = lambda x,y: np.sin(3*(x+y))
g = lambda x,y: np.sin(3*(x-y))
# %prun yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest4_1ms.csv',delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest4_1.csv', delimiter=',')

#verbose_pass_or_fail([f,g], yroots, m_sq_roots, 4.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 415
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 1.4458 95.9036  2.6506  0.      0.    ]

# %% [markdown]
# # Test 4.2
#
# YRoots fails to find an accurate approximation of f because our critera for an accurate approximation uses an absolute tolerance instead of a relative tolerance. We're looking into implementing a relative tolerance. In our initial tests, however, this causes issues with the Devil's Function from [your paper](https://link.springer.com/article/10.1007/s00211-014-0635-z) and a few other tests. Therefore, the results in this notebook were found using the code that uses and absolute tolerance.

# %%
# Test 4.2
# TODO Expect this one to freeze.
# TODO It keeps going too deep. Why?
f = lambda x,y: ((90000*y**10 + (-1440000)*y**9 + (360000*x**4 + 720000*x**3 + 504400*x**2 + 144400*x + 9971200)*(y**8) + 
            ((-4680000)*x**4 + (-9360000)*x**3 + (-6412800)*x**2 + (-1732800)*x + (-39554400))*(y**7) + (540000*x**8 + 
            2160000*x**7 + 3817600*x**6 + 3892800*x**5 + 27577600*x**4 + 51187200*x**3 + 34257600*x**2 + 8952800*x + 100084400)*(y**6) + 
            ((-5400000)*x**8 + (-21600000)*x**7 + (-37598400)*x**6 + (-37195200)*x**5 + (-95198400)*x**4 + 
            (-153604800)*x**3 + (-100484000)*x**2 + (-26280800)*x + (-169378400))*(y**5) + (360000*x**12 + 2160000*x**11 + 
            6266400*x**10 + 11532000*x**9 + 34831200*x**8 + 93892800*x**7 + 148644800*x**6 + 141984000*x**5 + 206976800*x**4 + 
            275671200*x**3 + 176534800*x**2 + 48374000*x + 194042000)*(y**4) + ((-2520000)*x**12 + (-15120000)*x**11 + (-42998400)*x**10 + 
            (-76392000)*x**9 + (-128887200)*x**8 + (-223516800)*x**7 + (-300675200)*x**6 + (-274243200)*x**5 + (-284547200)*x**4 + 
            (-303168000)*x**3 + (-190283200)*x**2 + (-57471200)*x + (-147677600))*(y**3) + (90000*x**16 + 720000*x**15 + 3097600*x**14 + 
            9083200*x**13 + 23934400*x**12 + 58284800*x**11 + 117148800*x**10 + 182149600*x**9 + 241101600*x**8 + 295968000*x**7 + 
            320782400*x**6 + 276224000*x**5 + 236601600*x**4 + 200510400*x**3 + 123359200*x**2 + 43175600*x + 70248800)*(y**2) + 
            ((-360000)*x**16 + (-2880000)*x**15 + (-11812800)*x**14 + (-32289600)*x**13 + (-66043200)*x**12 + (-107534400)*x**11 + 
            (-148807200)*x**10 + (-184672800)*x**9 + (-205771200)*x**8 + (-196425600)*x**7 + (-166587200)*x**6 + (-135043200)*x**5 + 
            (-107568800)*x**4 + (-73394400)*x**3 + (-44061600)*x**2 + (-18772000)*x + (-17896000))*y + (144400*x**18 + 1299600*x**17 + 
            5269600*x**16 + 12699200*x**15 + 21632000*x**14 + 32289600*x**13 + 48149600*x**12 + 63997600*x**11 + 67834400*x**10 + 
            61884000*x**9 + 55708800*x**8 + 45478400*x**7 + 32775200*x**6 + 26766400*x**5 + 21309200*x**4 + 11185200*x**3 + 6242400*x**2 + 
            3465600*x + 1708800)))
g = lambda x,y: 1e-4*(y**7 + (-3)*y**6 + (2*x**2 + (-1)*x + 2)*y**5 + (x**3 + (-6)*x**2 + x + 2)*y**4 + (x**4 + (-2)*x**3 + 2*x**2 + 
            x + (-3))*y**3 + (2*x**5 + (-3)*x**4 + x**3 + 10*x**2 + (-1)*x + 1)*y**2 + ((-1)*x**5 + 3*x**4 + 4*x**3 + (-12)*x**2)*y + 
            (x**7 + (-3)*x**5 + (-1)*x**4 + (-4)*x**3 + 4*x**2))
# %prun yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest4_2ms.csv',delimiter=',')
chebfun_roots = None

#verbose_pass_or_fail([f,g], yroots, m_sq_roots, 4.2, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 16.95%
# ---------------------------------------------------------------------------
# ConditioningError                         Traceback (most recent call last)
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     617         try:
# --> 618             zeros = multiplication(polys, max_cond_num=tols.max_cond_num, macaulay_zero_tol= tols.macaulay_zero_tol)
#     619             zeros = transform(good_zeros_nd(zeros,good_zeros_tol,good_zeros_tol),a,b)
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      59     except ConditioningError as e:
# ---> 60         raise e
#      61
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      57     try:
# ---> 58         m_f, var_dict = MSMultMatrix(polys, poly_type, verbose=verbose, MSmatrix=MSmatrix, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#      59     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     131     except ConditioningError as e:
# --> 132         raise e
#     133
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     129     try:
# --> 130         basisDict, VB = MacaulayReduction(polys, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol, verbose=verbose)
#     131     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     223     except ConditioningError as e:
# --> 224         raise e
#     225
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     221     try:
# --> 222         matrix, matrix_terms = rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#     223     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/MacaulayReduce.py in rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num, macaulay_zero_tol, return_perm)
#     118         raise ConditioningError("Conditioning number of the Macaulay matrix "\
# --> 119                                 + "after first QR is: " + str(cond_num))
#     120
#
# ConditioningError: Conditioning number of the Macaulay matrix after first QR is: 4084528061.3523984
#
# During handling of the above exception, another exception occurred:
#
# ConditioningError                         Traceback (most recent call last)
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     617         try:
# --> 618             zeros = multiplication(polys, max_cond_num=tols.max_cond_num, macaulay_zero_tol= tols.macaulay_zero_tol)
#     619             zeros = transform(good_zeros_nd(zeros,good_zeros_tol,good_zeros_tol),a,b)
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      59     except ConditioningError as e:
# ---> 60         raise e
#      61
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      57     try:
# ---> 58         m_f, var_dict = MSMultMatrix(polys, poly_type, verbose=verbose, MSmatrix=MSmatrix, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#      59     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     131     except ConditioningError as e:
# --> 132         raise e
#     133
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     129     try:
# --> 130         basisDict, VB = MacaulayReduction(polys, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol, verbose=verbose)
#     131     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     223     except ConditioningError as e:
# --> 224         raise e
#     225
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     221     try:
# --> 222         matrix, matrix_terms = rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#     223     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/MacaulayReduce.py in rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num, macaulay_zero_tol, return_perm)
#     118         raise ConditioningError("Conditioning number of the Macaulay matrix "\
# --> 119                                 + "after first QR is: " + str(cond_num))
#     120
#
# ConditioningError: Conditioning number of the Macaulay matrix after first QR is: 1041687735.1770821
#
# During handling of the above exception, another exception occurred:
#
# ConditioningError                         Traceback (most recent call last)
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     617         try:
# --> 618             zeros = multiplication(polys, max_cond_num=tols.max_cond_num, macaulay_zero_tol= tols.macaulay_zero_tol)
#     619             zeros = transform(good_zeros_nd(zeros,good_zeros_tol,good_zeros_tol),a,b)
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      59     except ConditioningError as e:
# ---> 60         raise e
#      61
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      57     try:
# ---> 58         m_f, var_dict = MSMultMatrix(polys, poly_type, verbose=verbose, MSmatrix=MSmatrix, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#      59     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     131     except ConditioningError as e:
# --> 132         raise e
#     133
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     129     try:
# --> 130         basisDict, VB = MacaulayReduction(polys, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol, verbose=verbose)
#     131     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     223     except ConditioningError as e:
# --> 224         raise e
#     225
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     221     try:
# --> 222         matrix, matrix_terms = rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#     223     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/MacaulayReduce.py in rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num, macaulay_zero_tol, return_perm)
#     118         raise ConditioningError("Conditioning number of the Macaulay matrix "\
# --> 119                                 + "after first QR is: " + str(cond_num))
#     120
#
# ConditioningError: Conditioning number of the Macaulay matrix after first QR is: 531357559.1568809
#
# During handling of the above exception, another exception occurred:
#
# ConditioningError                         Traceback (most recent call last)
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     617         try:
# --> 618             zeros = multiplication(polys, max_cond_num=tols.max_cond_num, macaulay_zero_tol= tols.macaulay_zero_tol)
#     619             zeros = transform(good_zeros_nd(zeros,good_zeros_tol,good_zeros_tol),a,b)
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      59     except ConditioningError as e:
# ---> 60         raise e
#      61
#
# ~/Research/RootFinding/yroots/Multiplication.py in multiplication(polys, max_cond_num, macaulay_zero_tol, verbose, MSmatrix, return_all_roots)
#      57     try:
# ---> 58         m_f, var_dict = MSMultMatrix(polys, poly_type, verbose=verbose, MSmatrix=MSmatrix, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#      59     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     131     except ConditioningError as e:
# --> 132         raise e
#     133
#
# ~/Research/RootFinding/yroots/Multiplication.py in MSMultMatrix(polys, poly_type, max_cond_num, macaulay_zero_tol, verbose, MSmatrix)
#     129     try:
# --> 130         basisDict, VB = MacaulayReduction(polys, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol, verbose=verbose)
#     131     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     223     except ConditioningError as e:
# --> 224         raise e
#     225
#
# ~/Research/RootFinding/yroots/Multiplication.py in MacaulayReduction(initial_poly_list, max_cond_num, macaulay_zero_tol, verbose)
#     221     try:
# --> 222         matrix, matrix_terms = rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num=max_cond_num, macaulay_zero_tol=macaulay_zero_tol)
#     223     except ConditioningError as e:
#
# ~/Research/RootFinding/yroots/MacaulayReduce.py in rrqr_reduceMacaulay(matrix, matrix_terms, cuts, max_cond_num, macaulay_zero_tol, return_perm)
#     118         raise ConditioningError("Conditioning number of the Macaulay matrix "\
# --> 119                                 + "after first QR is: " + str(cond_num))
#     120
#
# ConditioningError: Conditioning number of the Macaulay matrix after first QR is: 274283069.848097
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6fb718cfe565> in <module>
#      22             x + (-3))*y**3 + (2*x**5 + (-3)*x**4 + x**3 + 10*x**2 + (-1)*x + 1)*y**2 + ((-1)*x**5 + 3*x**4 + 4*x**3 + (-12)*x**2)*y +
#      23             (x**7 + (-3)*x**5 + (-1)*x**4 + (-4)*x**3 + 4*x**2))
# ---> 24 get_ipython().run_line_magic('prun', 'yroots = solve([f,g],[-1,-1],[1,1], plot=True)')
#      25 m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest4_2ms.csv',delimiter=',')
#      26 chebfun_roots = None
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </home/lukas/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-55> in prun(self, parameter_s, cell)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in prun(self, parameter_s, cell)
#     315             arg_str += '\n' + cell
#     316         arg_str = self.shell.transform_cell(arg_str)
# --> 317         return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#     318
#     319     def _run_with_profiler(self, code, opts, namespace):
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in _run_with_profiler(self, code, opts, namespace)
#     337         prof = profile.Profile()
#     338         try:
# --> 339             prof = prof.runctx(code, namespace, namespace)
#     340             sys_exit = ''
#     341         except SystemExit:
#
# ~/anaconda3/lib/python3.7/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>
#
# ~/Research/RootFinding/yroots/subdivision.py in solve(funcs, a, b, rel_approx_tol, abs_approx_tol, max_cond_num, macaulay_zero_tol, good_zeros_factor, min_good_zeros_tol, plot, plot_intervals, deg, max_level)
#     115
#     116     #Initial Solve
# --> 117     solve_func(funcs,a,b,deg,interval_data,root_tracker,tols,max_level)
#     118
#     119     #Polishing
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     610         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     611         for new_a, new_b in intervals:
# --> 612             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     613
#     614     #Solve using spectral methods if stable.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     610         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     611         for new_a, new_b in intervals:
# --> 612             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     613
#     614     #Solve using spectral methods if stable.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     610         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     611         for new_a, new_b in intervals:
# --> 612             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     613
#     614     #Solve using spectral methods if stable.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     610         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     611         for new_a, new_b in intervals:
# --> 612             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     613
#     614     #Solve using spectral methods if stable.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     624             intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     625             for new_a, new_b in intervals:
# --> 626                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     627
#     628 def trim_coeffs(coeffs, abs_approx_tol, rel_approx_tol, inf_norms, errors):
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     624             intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     625             for new_a, new_b in intervals:
# --> 626                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     627
#     628 def trim_coeffs(coeffs, abs_approx_tol, rel_approx_tol, inf_norms, errors):
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     624             intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     625             for new_a, new_b in intervals:
# --> 626                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     627
#     628 def trim_coeffs(coeffs, abs_approx_tol, rel_approx_tol, inf_norms, errors):
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     624             intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     625             for new_a, new_b in intervals:
# --> 626                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     627
#     628 def trim_coeffs(coeffs, abs_approx_tol, rel_approx_tol, inf_norms, errors):
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     604         intervals = get_subintervals(a,b,np.arange(dim),interval_data,cheb_approx_list,change_sign,approx_errors,True)
#     605         for new_a, new_b in intervals:
# --> 606             subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,good_degs,level+1)
#     607
#     608     #Runs the same things as above, but we want to get rid of that eventually so keep them seperate.
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     571             intervals = get_subintervals(a,b,change_sign,None,None,None,approx_errors)
#     572             for new_a, new_b in intervals:
# --> 573                 subdivision_solve_nd(funcs,new_a,new_b,deg,interval_data,root_tracker,tols,max_level,level=level+1)
#     574             return
#     575         else:
#
# ~/Research/RootFinding/yroots/subdivision.py in subdivision_solve_nd(funcs, a, b, deg, interval_data, root_tracker, tols, max_level, good_degs, level)
#     564     #Get the chebyshev approximations
#     565     for func, good_deg in zip(funcs, good_degs):
# --> 566         coeff,change_sign,inf_norm,approx_error = full_cheb_approximate(func,a,b,deg,tols.abs_approx_tol,tols.rel_approx_tol, good_deg)
#     567         inf_norms.append(inf_norm)
#     568         approx_errors.append(approx_error)
#
# ~/Research/RootFinding/yroots/subdivision.py in full_cheb_approximate(f, a, b, deg, abs_approx_tol, rel_approx_tol, good_deg)
#     422 #         return coeff, bools, inf_norm
#     423     #Try degree deg and see if it's good enough
# --> 424     coeff, inf_norm = interval_approximate_nd(f,a,b,deg)
#     425     coeff2, bools, inf_norm = interval_approximate_nd(f,a,b,deg*2,return_bools=True, inf_norm=inf_norm)
#     426     coeff2[slice_top(coeff)] -= coeff
#
# ~/Research/RootFinding/yroots/subdivision.py in interval_approximate_nd(f, a, b, deg, return_bools, inf_norm)
#     301         cheb_points = transform(get_cheb_grid(deg, dim, False), a, b)
#     302         cheb_points = [cheb_points[:,i] for i in range(dim)]
# --> 303         values_block = f(*cheb_points).reshape(*([deg+1]*dim))
#     304
#     305     #figure out on which subintervals the function changes sign
#
# <ipython-input-2-6fb718cfe565> in <lambda>(x, y)
#      15             ((-360000)*x**16 + (-2880000)*x**15 + (-11812800)*x**14 + (-32289600)*x**13 + (-66043200)*x**12 + (-107534400)*x**11 +
#      16             (-148807200)*x**10 + (-184672800)*x**9 + (-205771200)*x**8 + (-196425600)*x**7 + (-166587200)*x**6 + (-135043200)*x**5 +
# ---> 17             (-107568800)*x**4 + (-73394400)*x**3 + (-44061600)*x**2 + (-18772000)*x + (-17896000))*y + (144400*x**18 + 1299600*x**17 +
#      18             5269600*x**16 + 12699200*x**15 + 21632000*x**14 + 32289600*x**13 + 48149600*x**12 + 63997600*x**11 + 67834400*x**10 +
#      19             61884000*x**9 + 55708800*x**8 + 45478400*x**7 + 32775200*x**6 + 26766400*x**5 + 21309200*x**4 + 11185200*x**3 + 6242400*x**2 +
#
# KeyboardInterrupt:

# %%
# Test 5.1
f = lambda x,y: 2*x*y*np.cos(y**2)*np.cos(2*x)-np.cos(x*y)
g = lambda x,y: 2*np.sin(x*y**2)*np.sin(3*x*y)-np.sin(x*y)
# %prun -s cumulative yroots = solve([f,g],[-2,-2],[2,2], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest5_1ms.csv',delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest5_1.csv', delimiter=',')

#verbose_pass_or_fail([f,g], yroots, m_sq_roots, 5.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1381
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 5.6481 92.614   1.7379  0.      0.    ]

# %% [markdown]
# # Test 6.1
#
# Here, YRoots finds one more root than Chebfun finds. This is because a slight perturbation of the vertical line $g(0,y)$ turning it into $g(\epsilon,y)$ causes there to be two intersections along the two lines of $f$ when $g$ is approximated.

# %%
# Test 6.1
# No MS roots to compare to.
f = lambda x,y: (y - 2*x)*(y+0.5*x)
g = lambda x,y: x*(x**2+y**2-1)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest6_1.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots=None, test_num=6.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0.   0. 100.   0.]
# =========================================================
# Test 6.1
# 	 Residual test: pass
# 	 Chebfun passes residual test
# A different number of roots were found.
# Yroots: 6
# Chebfun Roots: 5
# YRoots max residuals:
# 	f0: 1.8494879441692063e-14
# 	f1: 1.0128739345248913e-14
# Chebfun max residuals:
# 	f0: 1.1326998971865292e-16
# 	f1: 1.9860273225978186e-16
# =========================================================

# %% [markdown]
# # Chebfun Norm Test
#
# Because of the different number of roots, the function we use to check if YRoots passes the norm test with chebfun can't be called. Below, we run the test manually to see that it passes almost exactly if we don't include the 2 roots near the origin from YRoots and the 1 root near the origin from Chebfun.

# %%
print("YRoots: ", yroots)
print("Chebfun Roots:", chebfun_roots)
# Take the roots not near the origin
yroots_4 = np.array([[ 4.47213595e-01,  8.94427191e-01],
 [-4.47213595e-01, -8.94427191e-01],
 [ 8.94427191e-01, -4.47213595e-01],
 [-8.94427191e-01,  4.47213595e-01]])

# Take the roots not near the origin
cheb_roots_4 = np.array([[-8.94427191e-01,  4.47213595e-01],
 [-4.47213595e-01, -8.94427191e-01],
 [ 4.47213595e-01,  8.94427191e-01],
 [ 8.94427191e-01, -4.47213595e-01]])

# Chebfun results
cheb_results, x_norm, y_norm = norm_pass_or_fail(yroots_4, cheb_roots_4)

if cheb_results:
    print("\nChebfun norm test: pass")
else:
    print("\nChebfun norm test: fails")

print("The norm of the difference in x values:", x_norm)
print("The norm of the difference in y values:", y_norm)
# Out:
# YRoots:  [[-4.47213595e-01 -8.94427191e-01]
#  [-8.94427191e-01  4.47213595e-01]
#  [-1.30171855e-16 -5.21297596e-16]
#  [-1.30171855e-16 -5.21297596e-16]
#  [ 8.94427191e-01 -4.47213595e-01]
#  [ 4.47213595e-01  8.94427191e-01]]
# Chebfun Roots: [[-8.94427191e-01  4.47213595e-01]
#  [-4.47213595e-01 -8.94427191e-01]
#  [-9.89338159e-18 -1.06428375e-08]
#  [ 4.47213595e-01  8.94427191e-01]
#  [ 8.94427191e-01 -4.47213595e-01]]
#
# Chebfun norm test: pass
# The norm of the difference in x values: 0.0
# The norm of the difference in y values: 0.0

# %% [markdown]
# # Test 6.2
# Comparing the results that YRoots found to the actual roots of the system, we find that YRoots correctly finds two roots near the origin, (.00001, -.000005) and (.00001, .00002), where there are two.
#
# We see that YRoots passes the residual test although Chebfun does not.
# <a id='test6.2'></a>

# %%
# Test 6.2
# This one we find more than them, but it's the correct number of roots.
# No MS roots to compare to.
f = lambda x,y: (y - 2*x)*(y+.5*x)
g = lambda x,y: (x-.0001)*(x**2+y**2-1)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest6_2.csv', delimiter=',')
actual_roots = np.array([[1/10000,-1/20000],[1/10000, 1/5000],[-2/np.sqrt(5),1/np.sqrt(5)],[-1/np.sqrt(5),-2/np.sqrt(5)],[1/np.sqrt(5),2/np.sqrt(5)],[2/np.sqrt(5),-1/np.sqrt(5)]])

verbose_pass_or_fail([f,g], yroots, MSroots=actual_roots, test_num=6.2, cheb_roots=chebfun_roots)

print(yroots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0.   0. 100.   0.]
# =========================================================
# Test 6.2
# 	 Residual test: pass
# 	 Chebfun fails residual test
# A different number of roots were found.
# Yroots: 6
# Chebfun Roots: 5
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 9.362167922248227e-15
# The norm of the difference in y values: 4.419559422404787e-13
# YRoots max residuals:
# 	f0: 2.482534153247293e-15
# 	f1: 1.430099544385986e-14
# Chebfun max residuals:
# 	f0: 1.1326998971865292e-16
# 	f1: 0.00010000000000000988
# MS/Actual max residuals:
# 	f0: 0.0
# 	f1: 9.931246836013717e-17
# Number of YRoots residual values <= MS/Actual residual values are: 0
# =========================================================
# [[-4.47213595e-01 -8.94427191e-01]
#  [ 4.47213595e-01  8.94427191e-01]
#  [-8.94427191e-01  4.47213595e-01]
#  [ 1.00000000e-04 -5.00000003e-05]
#  [ 1.00000000e-04  2.00000000e-04]
#  [ 8.94427191e-01 -4.47213595e-01]]

# %% [markdown]
# # Chebfun Norm Test
#
# Because of the different number of roots, the function we use to check if YRoots passes the norm test with chebfun can't be called. Below, we run the test manually to see that it passes almost exactly if we don't include the 2 roots near the origin from YRoots and the 1 root near the origin from Chebfun.

# %%
print("YRoots: ", yroots)
print("Chebfun Roots:", chebfun_roots)


# Remove the root (.0001, .0002) and (.0001, -.0005)
yroots_4 = np.array([[-4.47213595e-01, -8.94427191e-01],
 [-8.94427191e-01,  4.47213595e-01],
 [ 4.47213595e-01,  8.94427191e-01],
 [ 8.94427191e-01, -4.47213595e-01]])

# Take only 4 roots of chebfun's roots (not including near origin)
cheb_roots_4 = np.array([[-8.94427191e-01,  4.47213595e-01],
 [-4.47213595e-01, -8.94427191e-01],
 [ 4.47213595e-01,  8.94427191e-01],
 [ 8.94427191e-01, -4.47213595e-01]])

# Chebfun results
cheb_results, x_norm, y_norm = norm_pass_or_fail(yroots_4, cheb_roots_4)

if cheb_results:
    print("\nChebfun norm test: pass")
else:
    print("\nChebfun norm test: fails")

print("The norm of the difference in x values:", x_norm)
print("The norm of the difference in y values:", y_norm)
# Out:
# YRoots:  [[-4.47213595e-01 -8.94427191e-01]
#  [ 4.47213595e-01  8.94427191e-01]
#  [-8.94427191e-01  4.47213595e-01]
#  [ 1.00000000e-04 -5.00000003e-05]
#  [ 1.00000000e-04  2.00000000e-04]
#  [ 8.94427191e-01 -4.47213595e-01]]
# Chebfun Roots: [[-8.94427191e-01  4.47213595e-01]
#  [-4.47213595e-01 -8.94427191e-01]
#  [-9.89338159e-18 -1.06428375e-08]
#  [ 4.47213595e-01  8.94427191e-01]
#  [ 8.94427191e-01 -4.47213595e-01]]
#
# Chebfun norm test: pass
# The norm of the difference in x values: 0.0
# The norm of the difference in y values: 0.0

# %%
# Test 6.3
f = lambda x,y: 25*x*y - 12
g = lambda x,y: x**2+y**2-1
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest6_3ms.csv',delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest6_3.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 6.3, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0.   0. 100.   0.]
# =========================================================
# Test 6.3
# 	 Residual test: pass
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 3.6905523389740094e-15
# The norm of the difference in y values: 3.727109805583444e-15
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 2.3261755676969824e-15
# The norm of the difference in y values: 2.7307875685720004e-15
# YRoots max residuals:
# 	f0: 2.1316282072803006e-14
# 	f1: 1.1102230246251565e-15
# Chebfun max residuals:
# 	f0: 5.329070518200751e-15
# 	f1: 4.440892098500626e-16
# MS/Actual max residuals:
# 	f0: 0.0
# 	f1: 0.0
# Number of YRoots residual values <= MS/Actual residual values are: 1
# Number of YRoots residual values <= to Chebfun residual values are: 5
# =========================================================

# %%
# Test 7.1
f = lambda x,y: (x**2+y**2-1)*(x-1.1)
g = lambda x,y: (25*x*y-12)*(x-1.1)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest7_1ms.csv',delimiter=',')
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest7_1.csv', delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 7.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1693
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.1181 98.1689  1.7129  0.      0.    ]
# =========================================================
# Test 7.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 1.286960167255997e-13
# The norm of the difference in y values: 4.9767349229316397e-14
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 1.2859426270150552e-13
# The norm of the difference in y values: 4.959206065127418e-14
# YRoots max residuals:
# 	f0: 3.474998067075883e-14
# 	f1: 8.659739592074084e-13
# Chebfun max residuals:
# 	f0: 2.2648549702353208e-15
# 	f1: 3.623767952376513e-14
# MS/Actual max residuals:
# 	f0: 2.2204460492503091e-16
# 	f1: 2.664535259100371e-15
# Number of YRoots residual values <= MS/Actual residual values are: 0
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %% [markdown]
# # Test 7.2
#
# It appears that YRoots has a hard time accurately approximating g. It takes several (13+) subdivisions in order to get it accurate enough, which means there are a lot of subintervals to go through, which causes this test to freeze.
#
# 5 levels down, we can get the approximation to just above 1e-10, but it's not accurate enough for our default tolerance (which is 1e-10). Hence, if we change the tolerance to 1e-9, YRoots finds the solution quickly but doesn't pass the residual test.
#
# Just like with test 4.2, we're looking into implementing relative tolereances that may help with this problem.

# %%
# Test 7.2
f = lambda x,y: y**4 + (-1)*y**3 + (2*x**2)*(y**2) + (3*x**2)*y + (x**4)
h = lambda x,y: y**10-2*(x**8)*(y**2)+4*(x**4)*y-2
g = lambda x,y: h(2*x,2*(y+.5))
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest7_2.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots=None, cheb_roots=chebfun_roots, test_num=7.2, tol=2.220446049250313e-11)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1231
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 1.4622 97.0755  1.4622  0.      0.    ]
# =========================================================
# Test 7.2
# 	 Residual test: pass
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 9.446283062070915e-10
# The norm of the difference in y values: 3.971344800185499e-08
# YRoots max residuals:
# 	f0: 1.1830814106161824e-14
# 	f1: 5.724309914967307e-13
# Chebfun max residuals:
# 	f0: 4.163336342344337e-16
# 	f1: 1.3376411089893736e-11
# Number of YRoots residual values <= to Chebfun residual values are: 11
# =========================================================

# %%
# Test 7.3
c = 1.e-09
f = lambda x,y: np.cos(x*y/(c**2))+np.sin(3*x*y/(c**2))
g = lambda x,y: np.cos(y/c)-np.cos(2*x*y/(c**2))
#yroots = solve([f,g], [-1,-1],[1,1], plot=True, approx_tol=1.e-5)
yroots = solve([f,g],[-1e-9, -1e-9],[1e-9, 1e-9], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest7_3.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots=None, cheb_roots=chebfun_roots, test_num=7.3, tol=2.220446049250313e-9)

print(yroots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 319
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 4.0752 94.3574  1.5674  0.      0.    ]
# =========================================================
# Test 7.3
# 	 Residual test: pass
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 2.685652483343685e-22
# The norm of the difference in y values: 6.851937088801247e-22
# YRoots max residuals:
# 	f0: 2.049471703458039e-13
# 	f1: 2.9465319073551655e-13
# Chebfun max residuals:
# 	f0: 5.551115123125783e-16
# 	f1: 1.1102230246251565e-16
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================
# [[ 5.00000000e-10 -7.85398163e-10]
#  [-5.00000000e-10  7.85398163e-10]]

# %%
# Test 7.4
f = lambda x,y: np.sin(3*np.pi*x)*np.cos(x*y)
g = lambda x,y: np.sin(3*np.pi*y)*np.cos(np.sin(x*y))
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest7_4.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, MSroots=None, cheb_roots=chebfun_roots, test_num=7.4)
# Out:
# Percent Finished: 100%
# Total intervals checked was 2530
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 3.7154 94.3478  1.9368  0.      0.    ]
# =========================================================
# Test 7.4
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 6.244585286907133e-13
# The norm of the difference in y values: 5.896562550802349e-13
# YRoots max residuals:
# 	f0: 4.174683501950418e-12
# 	f1: 4.174683501950418e-12
# Chebfun max residuals:
# 	f0: 3.2310891488651735e-15
# 	f1: 3.2310891488651735e-15
# Number of YRoots residual values <= to Chebfun residual values are: 2
# =========================================================

# %%
# Test 8.1
f = lambda x,y: np.sin(10*x-y/10)
g = lambda x,y: np.cos(3*x*y)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest8_1ms.csv',delimiter=',')
chebfun_roots =  np.loadtxt('tests/chebfun_test_output/cftest8_1.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 8.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 934
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [10.1713 88.2227  1.606   0.      0.    ]
# =========================================================
# Test 8.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 3.643494191112748e-15
# The norm of the difference in y values: 3.884333537546203e-13
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 3.643494191112748e-15
# The norm of the difference in y values: 3.884333537546203e-13
# YRoots max residuals:
# 	f0: 1.4089627996560444e-15
# 	f1: 5.263069460122816e-13
# Chebfun max residuals:
# 	f0: 3.920107718544707e-15
# 	f1: 6.049014748177263e-16
# MS/Actual max residuals:
# 	f0: 3.920107718544707e-15
# 	f1: 6.049014748177263e-16
# Number of YRoots residual values <= MS/Actual residual values are: 5
# Number of YRoots residual values <= to Chebfun residual values are: 11
# =========================================================

# %%
# Test 8.2 
f = lambda x,y: np.sin(10*x-y/10) + y
g = lambda x,y: np.cos(10*y-x/10) - x
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest8_2ms.csv',delimiter=',')
chebfun_roots =  np.loadtxt('tests/chebfun_test_output/cftest8_2.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 8.2, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 3070
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 2.7362 95.7329  1.5309  0.      0.    ]
# =========================================================
# Test 8.2
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: fail
# The norm of the difference in x values: 2.277245276596564e-13
# The norm of the difference in y values: 3.4825686762759546e-13
# 	 MS/Actual norm test: fail
# The norm of the difference in x values: 2.285862983438049e-13
# The norm of the difference in y values: 3.5280837367790276e-13
# YRoots max residuals:
# 	f0: 7.385203559806541e-13
# 	f1: 8.079092950197264e-13
# Chebfun max residuals:
# 	f0: 7.327471962526033e-15
# 	f1: 7.105427357601002e-15
# MS/Actual max residuals:
# 	f0: 4.9404924595819466e-15
# 	f1: 4.218847493575595e-15
# Number of YRoots residual values <= MS/Actual residual values are: 1
# Number of YRoots residual values <= to Chebfun residual values are: 2
# =========================================================

# %%
# Test 9.1
f = lambda x,y: x**2+y**2-.9**2
g = lambda x,y: np.sin(x*y)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest9_1ms.csv',delimiter=',')
chebfun_roots =  np.loadtxt('tests/chebfun_test_output/cftest9_1.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 9.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 256
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 0.     98.4375  1.5625  0.      0.    ]
# =========================================================
# Test 9.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 1.7480230033049699e-13
# The norm of the difference in y values: 1.748077056863399e-13
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 1.7479743001248745e-13
# The norm of the difference in y values: 1.747969983767e-13
# YRoots max residuals:
# 	f0: 2.7144952952085077e-13
# 	f1: 7.46539584663427e-14
# Chebfun max residuals:
# 	f0: 0.0
# 	f1: 7.916332619193067e-18
# MS/Actual max residuals:
# 	f0: 0.0
# 	f1: 4.51580476975047e-17
# Number of YRoots residual values <= MS/Actual residual values are: 0
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %%
# Test 9.2
f = lambda x,y: x**2+y**2-.49**2
g = lambda x,y: (x-.1)*(x*y - .2)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
m_sq_roots = np.loadtxt('tests/chebfun_test_output/cftest9_2ms.csv',delimiter=',')
chebfun_roots =  np.loadtxt('tests/chebfun_test_output/cftest9_2.csv',delimiter=',')

verbose_pass_or_fail([f,g], yroots, m_sq_roots, 9.2, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 1
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [  0.   0.   0. 100.   0.]
# =========================================================
# Test 9.2
# 	 Residual test: pass
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 7.159714684593435e-15
# The norm of the difference in y values: 4.3737714791252564e-15
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 7.304477079183743e-15
# The norm of the difference in y values: 4.3737714791252564e-15
# YRoots max residuals:
# 	f0: 2.3037127760972e-15
# 	f1: 1.0739175025807764e-15
# Chebfun max residuals:
# 	f0: 3.0531133177191805e-16
# 	f1: 1.5190974496230676e-16
# MS/Actual max residuals:
# 	f0: 1.942890293094024e-16
# 	f1: 0.0
# Number of YRoots residual values <= MS/Actual residual values are: 0
# Number of YRoots residual values <= to Chebfun residual values are: 0
# =========================================================

# %%
# Test 10.1
f = lambda x,y: (x-1)*(np.cos(x*y**2)+2)
g = lambda x,y: np.sin(8*np.pi*y)*(np.cos(x*y)+2)
yroots = solve([f,g],[-1,-1],[1,1], plot=True)
chebfun_roots = np.loadtxt('tests/chebfun_test_output/cftest10_1.csv',delimiter=',')
actual_roots = np.array([[1, -1.0], [1, -0.875], [1, -0.75], [1, -0.625], [1, -0.5], [1, -0.375],
                         [1, -0.25], [1, -0.125], [1, 0.0], [1, 0.125], [1, 0.25], [1, 0.375],
                         [1, 0.5], [1, 0.625], [1, 0.75], [1, 0.875], [1, 1.0]])

verbose_pass_or_fail([f,g], yroots, actual_roots, 10.1, cheb_roots=chebfun_roots)
# Out:
# Percent Finished: 100%
# Total intervals checked was 934
# Methods used were ['constant_term_check', 'quadratic_check', 'Base Case', 'Spectral', 'Too Deep']
# The percent solved by each was [ 9.1006 89.0792  1.8201  0.      0.    ]
# /home/lukas/Research/RootFinding/yroots/IntervalChecks.py:261: UserWarning: No contour levels were found within the data range.
#   plt.contour(X,Y,funcs[i](X,Y),levels=[0],colors=contour_colors[i])
# =========================================================
# Test 10.1
# 	 Residual test: fail
# 	 Chebfun passes residual test
# 	 Chebfun norm test: pass
# The norm of the difference in x values: 2.2029186144272493e-14
# The norm of the difference in y values: 3.466424398889035e-14
# 	 MS/Actual norm test: pass
# The norm of the difference in x values: 2.2029186144272493e-14
# The norm of the difference in y values: 3.4664719969702115e-14
# YRoots max residuals:
# 	f0: 3.4437811427846676e-14
# 	f1: 1.2999354769340216e-12
# Chebfun max residuals:
# 	f0: 0.0
# 	f1: 2.4887784701984463e-15
# MS/Actual max residuals:
# 	f0: 0.0
# 	f1: 2.4887784701984463e-15
# Number of YRoots residual values <= MS/Actual residual values are: 1
# Number of YRoots residual values <= to Chebfun residual values are: 2
# =========================================================

# %% [markdown]
# # Necessary Functions
# <a id='neededfuncs'></a>

# %%
# Define the tests for pass/fail, residuals

def norm_pass_or_fail(yroots, roots, tol=2.220446049250313e-13):
    """ Determines whether the roots given pass or fail the test according
        to whether or not their norms are within tol of the norms of the 
        "actual" roots, which are determined either by previously known 
        roots or Marching Squares roots.

    Parameters
    ----------
        yroots : numpy array
            The roots that yroots found.
        roots : numpy array
            "Actual" roots either obtained analytically or through Marching
            Squares.
        tol : float, optional
            Tolerance that determines how close the roots need to be in order
            to be considered close. Defaults to 1000*eps where eps is machine
            epsilon.
    
    Returns
    -------
         bool
            Whether or not all the roots were close enough.

    """
    roots_sorted = np.sort(roots,axis=0)
    yroots_sorted = np.sort(yroots,axis=0)
    root_diff = roots_sorted - yroots_sorted
    return np.linalg.norm(root_diff[:,0]) < tol and np.linalg.norm(root_diff[:,1]) < tol, np.linalg.norm(root_diff[:,0]), np.linalg.norm(root_diff[:,1])


def residuals(func, roots):
    """ Finds the residuals of the given function at the roots.

    Paramters
    ---------
        func : function
            The function to find the residuals of.
        roots : numpy array
            The coordinates of the roots.
    
    Returns
    -------
        numpy array
            The residuals of the function.

    """
    return np.abs(func(roots[:,0],roots[:,1]))


def residuals_pass_or_fail(funcs, roots, tol=2.220446049250313e-13):
    """ Determines whether the roots given pass or fail the test according
        to whether or not the maximal residuals are within a certain tolerance.

    Parameters
    ----------
        funcs : list of functions
            The functions to find the residuals of.
        roots : numpy array
            The roots to plug into the functions to get the residuals.
        tol : float, optional
            How close to 0 the maximal residual must be in order to pass.
            Defaults to 1000* eps where eps is machine epsilon.

    Returns
    -------
        bool
            True if the roots pass the test (are close enough to 0), False
            otherwise.

    """
    for func in funcs:
        if np.max(residuals(func, roots)) > tol:
            return False
    
    return True

def verbose_pass_or_fail(funcs, yroots, MSroots, test_num, cheb_roots=None, tol=2.220446049250313e-13):
    """ Determines which tests pass and which fail.

    Parameters
    ----------
        funcs : list of functions
            The functions to find the roots of.
        yroots : numpy array
            Roots found by yroots.
        MSroots : numpy array
            The list of "actual" or Marching Squares roots.
        test_num : float or string
            The number of the test. For example, test 9.2 one could pass in
            "9.2" or 9.2.
        cheb_roots : numpy array
            Chebfun roots for extra comparison when MS are available.
        tol : float, optional
            The tolerance with which we want to run our tests. Defualts to
            1000*eps where eps is machine epsilon.

    Raises
    ------
        AssertionError
            If len(yroots) != len(roots) or if it fails the residual 
            or norm tests.
    """
    print ("=========================================================")
    print("Test " + str(test_num))

    if residuals_pass_or_fail(funcs, yroots, tol):
        print("\t Residual test: pass")
    else:
        print("\t Residual test: fail")
    
    if cheb_roots is not None:
        if residuals_pass_or_fail(funcs, cheb_roots, tol):
            print("\t Chebfun passes residual test")
        else:
            print("\t Chebfun fails residual test")
        try:
            result, x_norm, y_norm = norm_pass_or_fail(yroots, cheb_roots, tol)
            if result:
                print("\t Chebfun norm test: pass")
            else:
                print("\t Chebfun norm test: fail")
            print("The norm of the difference in x values:", x_norm)
            print("The norm of the difference in y values:", y_norm)
        except ValueError as e:
            print("A different number of roots were found.")
            print ("Yroots: " + str(len(yroots)))
            print("Chebfun Roots: " + str(len(cheb_roots)))
    if MSroots is not None:
        try:
            result, x_norm, y_norm = norm_pass_or_fail(yroots, MSroots, tol)
            if result:
                print("\t MS/Actual norm test: pass")
            else:
                print("\t MS/Actual norm test: fail")
            print("The norm of the difference in x values:", x_norm)
            print("The norm of the difference in y values:", y_norm)
        except ValueError as e:
                print("A different number of roots were found.")
                print ("Yroots: " + str(len(yroots)))
                print("MS/Actual: " + str(len(MSroots)))
        
    print("YRoots max residuals:")
    YR_resid = list()
    for i, func in enumerate(funcs):
        YR_resid.append(residuals(func, yroots))
        print("\tf" + str(i) + ": " + str(np.max(residuals(func, yroots))))
        
    cheb_resid = None
    if cheb_roots is not None:
        cheb_resid = list()
        print("Chebfun max residuals:")
        for i, func in enumerate(funcs):
            cheb_resid.append(residuals(func, cheb_roots))
            print("\tf" + str(i) + ": " + str(np.max(residuals(func, cheb_roots))))
    if MSroots is not None:
        print("MS/Actual max residuals:")
        Other_resid = list()
        for i, func in enumerate(funcs):
            Other_resid.append(residuals(func, MSroots))
            print("\tf" + str(i) + ": " + str(np.max(residuals(func, MSroots))))

        if len(yroots) > len(MSroots):
            print("YRoots found more roots.")
            print("=========================================================")
            return

    # print("Comparison of Residuals (YRoots <= Other)")
    num_smaller = 0
    if MSroots is not None:
        for i in range(len(YR_resid)):
            comparison_array = (YR_resid[i] <= Other_resid[i])
            # print(comparison_array)
            num_smaller += np.sum(comparison_array)
        print("Number of YRoots residual values <= MS/Actual residual values are: " + str(num_smaller))
    
    if cheb_resid is not None:
        if len(yroots) > len(cheb_roots):
            print("=========================================================")
            return
        
        for i in range(len(YR_resid)):
            comparison_array2 = (YR_resid[i] <= cheb_resid[i])
            num_smaller += np.sum(comparison_array2)
    print("Number of YRoots residual values <= to Chebfun residual values are: " + str(num_smaller))

    print("=========================================================")
